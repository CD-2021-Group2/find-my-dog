# %% [markdown]
# <h3>Google Image Scrapper for Juypter Notebook</h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import os

# %%
dog = pd.read_csv('dog_data_Fe.csv',encoding='latin1')

# %%
dog
# Out:
#                      Breed  minhegiht  maxhegiht  minweight  maxweight
# 0                  Maltese         20         23        3.0        4.0
# 1               Toy Poodle          0         23        2.0        3.0
# 2         Standard Poodle          45         60       20.0       27.0
# 3         Miniature Poodle         25         35        3.0        6.0
# 4           Japanese Spits         25         35        3.5        5.0
# ..                     ...        ...        ...        ...        ...
# 70                  Borzoi         68         78       25.0       40.0
# 71           Silky Terrier         24         26        3.5        4.6
# 72  Caucasian Shepherd Dog         63         71       46.0       66.0
# 73             Pointer Dog         53         66       16.0       30.0
# 74              Great Dane         45         59       71.0       81.0
#
# [75 rows x 5 columns]

# %%
doglst = list(dog['Breed'])

# %%
len(doglst)
# Out:
# 75

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Hannah Kim\\Downloads\\Google-Image-Scraper-master\\Google-Image-Scraper-master'

# %%
os.chdir('C:/Users/Hannah Kim/Documents/외대/21-1/종설')

# %%
from GoogleImageScrapper import GoogleImageScraper
import os

webdriver_path = os.getcwd()+"\\webdriver\\chromedriver.exe"
image_path = os.getcwd()+"\\photos"
#add new search key into array ["cat","t-shirt","apple","orange","pear","fish"]
search_keys= doglst
number_of_images = 100
headless = False
#min_resolution = (width,height)
min_resolution=(0,0)
#max_resolution = (width,height)
max_resolution=(1920,1080)
for search_key in search_keys:
    #os.chdir('C:\\Users\\Hannah Kim\\Downloads\\Google-Image-Scraper-master\\Google-Image-Scraper-master')
    path = "C:/Users/Hannah Kim/Documents/외대/21-1/종설/google_data/" + search_key
    image_scrapper = GoogleImageScraper(webdriver_path,path,search_key,number_of_images,headless,min_resolution,max_resolution)
    image_urls = image_scrapper.find_image_urls()
    #os.mkdir(path)
    #os.chdir(path)
    image_scrapper.save_images(image_urls)
# Out:
# [+] Scraping for image link... Please wait.
# 0. https://i.pinimg.com/originals/06/d0/06/06d0066e7e0b62fd63b1e4bab92205df.jpg
# 1. https://dogtime.com/assets/uploads/gallery/maltese-dog-breed-picture/9-fullbody.jpg
# 2. https://www.dogtime.com/assets/uploads/2011/01/file_23114_maltese.jpg
# 3. https://media.istockphoto.com/photos/white-maltese-dog-running-picture-id547009100
# 4. https://www.rover.com/blog/wp-content/uploads/2019/07/maltese-puppy-960x540.jpg
# 5. https://www.thesprucepets.com/thmb/7e9M80FnFlNff3GjyPj9XPfLARM=/2529x2529/smart/filters:no_upscale()/Malteseportrait-GettyImages-153520182-1eb5302d0f184d02b509fcf05348d64e.jpg
# 6. https://www.thegoodypet.com/wp-content/uploads/2020/09/do-maltese-bark-alot-what-can-i-do-about-it.jpg
# 7. http://imagescdn.gettyimagesbank.com/500/20/923/458/0/1257261633.jpg
# 8. https://www.petfirst.com/wp-content/uploads/2018/03/Breed-Hero-Maltese.jpg
# ...

# %% [markdown]
# 참고: https://www.youtube.com/watch?v=QZn_ZxpsIw4
